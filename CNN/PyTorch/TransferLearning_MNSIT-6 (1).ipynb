# %% [markdown]
# In this notebook, we apply transfer learning on VGG-16 network and solve MNSIT digit classifiation task very rapidly.

# %% [markdown]
# # Transfer learning - Fixed Feature Extractor

# %% [markdown]
# ## Creating and using a Fixed Feature Extractor

# %%
# Setting seeds to try and ensure we have the same results - this is not guaranteed across PyTorch releases.
import torch
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
mean = [0.1307]
std = [0.3081]

transform =transforms.Compose([
   transforms.Resize((224, 224)),
   transforms.ToTensor(),
   transforms.Normalize((0.1307,), (0.3081,)),
   transforms.Lambda(lambda x: x.repeat(3, 1, 1))
   
])
trainset = datasets.MNIST(root='~/.pytorch/MNIST',train=True, download=True,transform=transform)
testset = datasets.MNIST(root='~/.pytorch/MNIST',train=False, transform=transform)

trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
testloader = DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST/MNIST/raw

# %%
model = models.vgg16(pretrained=True)
model.features
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
  param.requires_grad=False

# %%
model.classifier[-1]=nn.Sequential(nn.Linear(in_features=4096, out_features=10),nn.LogSoftmax(dim=1))
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Sequential(
#     (0): Linear(in_features=4096, out_features=10, bias=True)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %%
criterion=nn.NLLLoss()

# %% [markdown]
# ## Training the Fixed Feature Extractor

# %%
from torch.optim import Adam

model = model.to(device)
optimizer = Adam(model.parameters())

# %%
num_epochs = 1
batch_loss = 0
cum_epoch_loss = 0

for e in range(num_epochs):
  cum_epoch_loss = 0
  
  for batch, (images, labels) in enumerate(trainloader,1):
    images = images.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    logps = model(images)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()
    
    batch_loss += loss.item()
    print(f'Epoch({e}/{num_epochs} : Batch number({batch}/{len(trainloader)})  Batch loss : {loss.item()}')
    
  print(f'Training loss : {batch_loss/len(trainloader)}')
# Out:
# Epoch(0/1 : Batch number(1/938)  Batch loss : 2.355513572692871
# Epoch(0/1 : Batch number(2/938)  Batch loss : 2.3121888637542725
# Epoch(0/1 : Batch number(3/938)  Batch loss : 2.2674596309661865
# Epoch(0/1 : Batch number(4/938)  Batch loss : 2.202890157699585
# Epoch(0/1 : Batch number(5/938)  Batch loss : 1.9799960851669312
# Epoch(0/1 : Batch number(6/938)  Batch loss : 1.870864748954773
# Epoch(0/1 : Batch number(7/938)  Batch loss : 1.8888568878173828
# Epoch(0/1 : Batch number(8/938)  Batch loss : 1.8657402992248535
# Epoch(0/1 : Batch number(9/938)  Batch loss : 1.5870283842086792
# Epoch(0/1 : Batch number(10/938)  Batch loss : 1.6474915742874146
# Epoch(0/1 : Batch number(11/938)  Batch loss : 1.647162914276123
# Epoch(0/1 : Batch number(12/938)  Batch loss : 1.483595371246338
# Epoch(0/1 : Batch number(13/938)  Batch loss : 1.4254322052001953
# Epoch(0/1 : Batch number(14/938)  Batch loss : 1.4069381952285767
# Epoch(0/1 : Batch number(15/938)  Batch loss : 1.2985435724258423
# Epoch(0/1 : Batch number(16/938)  Batch loss : 1.5336698293685913
# Epoch(0/1 : Batch number(17/938)  Batch loss : 1.3770778179168701
# Epoch(0/1 : Batch number(18/938)  Batch loss : 1.3524224758148193
# Epoch(0/1 : Batch number(19/938)  Batch loss : 1.3340562582015991
# Epoch(0/1 : Batch number(20/938)  Batch loss : 1.191535234451294
# Epoch(0/1 : Batch number(21/938)  Batch loss : 1.3245307207107544
# Epoch(0/1 : Batch number(22/938)  Batch loss : 1.150437593460083
# Epoch(0/1 : Batch number(23/938)  Batch loss : 1.0432192087173462
# Epoch(0/1 : Batch number(24/938)  Batch loss : 1.1654505729675293
# Epoch(0/1 : Batch number(25/938)  Batch loss : 0.93650221824646
# Epoch(0/1 : Batch number(26/938)  Batch loss : 0.926127016544342
# Epoch(0/1 : Batch number(27/938)  Batch loss : 1.1294598579406738
# Epoch(0/1 : Batch number(28/938)  Batch loss : 1.063805103302002
# Epoch(0/1 : Batch number(29/938)  Batch loss : 1.1031849384307861
# Epoch(0/1 : Batch number(30/938)  Batch loss : 1.0290591716766357
# Epoch(0/1 : Batch number(31/938)  Batch loss : 1.114439606666565
# Epoch(0/1 : Batch number(32/938)  Batch loss : 1.0046336650848389
# Epoch(0/1 : Batch number(33/938)  Batch loss : 0.9354184865951538
# Epoch(0/1 : Batch number(34/938)  Batch loss : 0.8888626098632812
# Epoch(0/1 : Batch number(35/938)  Batch loss : 0.9655646085739136
# Epoch(0/1 : Batch number(36/938)  Batch loss : 0.9011924266815186
# Epoch(0/1 : Batch number(37/938)  Batch loss : 1.0808526277542114
# Epoch(0/1 : Batch number(38/938)  Batch loss : 0.9571325182914734
# Epoch(0/1 : Batch number(39/938)  Batch loss : 0.8999521732330322
# Epoch(0/1 : Batch number(40/938)  Batch loss : 0.8333411812782288
# Epoch(0/1 : Batch number(41/938)  Batch loss : 0.817476212978363
# Epoch(0/1 : Batch number(42/938)  Batch loss : 0.7147648334503174
# Epoch(0/1 : Batch number(43/938)  Batch loss : 0.7218011617660522
# Epoch(0/1 : Batch number(44/938)  Batch loss : 0.9561091661453247
# Epoch(0/1 : Batch number(45/938)  Batch loss : 0.6357853412628174
# Epoch(0/1 : Batch number(46/938)  Batch loss : 0.975818395614624
# Epoch(0/1 : Batch number(47/938)  Batch loss : 0.9888435006141663
# Epoch(0/1 : Batch number(48/938)  Batch loss : 0.8855941295623779
# Epoch(0/1 : Batch number(49/938)  Batch loss : 0.8802001476287842
# Epoch(0/1 : Batch number(50/938)  Batch loss : 0.8525018095970154
# Epoch(0/1 : Batch number(51/938)  Batch loss : 0.7845888733863831
# Epoch(0/1 : Batch number(52/938)  Batch loss : 0.709110677242279
# Epoch(0/1 : Batch number(53/938)  Batch loss : 0.7388119697570801
# Epoch(0/1 : Batch number(54/938)  Batch loss : 0.8035407662391663
# Epoch(0/1 : Batch number(55/938)  Batch loss : 0.7535165548324585
# Epoch(0/1 : Batch number(56/938)  Batch loss : 0.7710731625556946
# Epoch(0/1 : Batch number(57/938)  Batch loss : 0.7093347907066345
# Epoch(0/1 : Batch number(58/938)  Batch loss : 0.6786465644836426
# Epoch(0/1 : Batch number(59/938)  Batch loss : 0.8270218968391418
# Epoch(0/1 : Batch number(60/938)  Batch loss : 0.9523674845695496
# Epoch(0/1 : Batch number(61/938)  Batch loss : 0.7989166378974915
# Epoch(0/1 : Batch number(62/938)  Batch loss : 0.6412328481674194
# Epoch(0/1 : Batch number(63/938)  Batch loss : 0.7684553265571594
# Epoch(0/1 : Batch number(64/938)  Batch loss : 0.6980213522911072
# Epoch(0/1 : Batch number(65/938)  Batch loss : 0.7194023132324219
# Epoch(0/1 : Batch number(66/938)  Batch loss : 0.7698246240615845
# Epoch(0/1 : Batch number(67/938)  Batch loss : 0.7635498642921448
# Epoch(0/1 : Batch number(68/938)  Batch loss : 0.8029856085777283
# Epoch(0/1 : Batch number(69/938)  Batch loss : 0.9102489352226257
# Epoch(0/1 : Batch number(70/938)  Batch loss : 0.6804654598236084
# Epoch(0/1 : Batch number(71/938)  Batch loss : 0.7167242169380188
# Epoch(0/1 : Batch number(72/938)  Batch loss : 0.8910971283912659
# Epoch(0/1 : Batch number(73/938)  Batch loss : 0.7239092588424683
# Epoch(0/1 : Batch number(74/938)  Batch loss : 0.666100800037384
# Epoch(0/1 : Batch number(75/938)  Batch loss : 0.7374945282936096
# Epoch(0/1 : Batch number(76/938)  Batch loss : 0.8147698044776917
# Epoch(0/1 : Batch number(77/938)  Batch loss : 0.6948322653770447
# Epoch(0/1 : Batch number(78/938)  Batch loss : 0.6153882741928101
# Epoch(0/1 : Batch number(79/938)  Batch loss : 0.7043041586875916
# Epoch(0/1 : Batch number(80/938)  Batch loss : 0.6404229402542114
# Epoch(0/1 : Batch number(81/938)  Batch loss : 0.6273060441017151
# Epoch(0/1 : Batch number(82/938)  Batch loss : 0.8214473128318787
# Epoch(0/1 : Batch number(83/938)  Batch loss : 0.7890917658805847
# Epoch(0/1 : Batch number(84/938)  Batch loss : 0.6213197708129883
# Epoch(0/1 : Batch number(85/938)  Batch loss : 0.7147542238235474
# Epoch(0/1 : Batch number(86/938)  Batch loss : 0.6652953624725342
# Epoch(0/1 : Batch number(87/938)  Batch loss : 0.7791725993156433
# Epoch(0/1 : Batch number(88/938)  Batch loss : 0.7714320421218872
# Epoch(0/1 : Batch number(89/938)  Batch loss : 0.8705318570137024
# Epoch(0/1 : Batch number(90/938)  Batch loss : 0.6839832067489624
# Epoch(0/1 : Batch number(91/938)  Batch loss : 0.746060848236084
# Epoch(0/1 : Batch number(92/938)  Batch loss : 0.6231859922409058
# Epoch(0/1 : Batch number(93/938)  Batch loss : 0.46705764532089233
# Epoch(0/1 : Batch number(94/938)  Batch loss : 0.5563263297080994
# Epoch(0/1 : Batch number(95/938)  Batch loss : 0.6041842699050903
# Epoch(0/1 : Batch number(96/938)  Batch loss : 0.7492567896842957
# Epoch(0/1 : Batch number(97/938)  Batch loss : 0.7510399222373962
# Epoch(0/1 : Batch number(98/938)  Batch loss : 0.6765042543411255
# Epoch(0/1 : Batch number(99/938)  Batch loss : 0.6770903468132019
# Epoch(0/1 : Batch number(100/938)  Batch loss : 0.6440256237983704
# Epoch(0/1 : Batch number(101/938)  Batch loss : 0.5984933972358704
# Epoch(0/1 : Batch number(102/938)  Batch loss : 0.5811935067176819
# Epoch(0/1 : Batch number(103/938)  Batch loss : 0.6404411196708679
# Epoch(0/1 : Batch number(104/938)  Batch loss : 0.7935052514076233
# Epoch(0/1 : Batch number(105/938)  Batch loss : 0.6417597532272339
# Epoch(0/1 : Batch number(106/938)  Batch loss : 0.5673782229423523
# Epoch(0/1 : Batch number(107/938)  Batch loss : 0.7210296392440796
# Epoch(0/1 : Batch number(108/938)  Batch loss : 0.6386041045188904
# Epoch(0/1 : Batch number(109/938)  Batch loss : 0.5697514414787292
# Epoch(0/1 : Batch number(110/938)  Batch loss : 0.853263795375824
# Epoch(0/1 : Batch number(111/938)  Batch loss : 0.6542029976844788
# Epoch(0/1 : Batch number(112/938)  Batch loss : 0.6044261455535889
# Epoch(0/1 : Batch number(113/938)  Batch loss : 0.5958306789398193
# Epoch(0/1 : Batch number(114/938)  Batch loss : 0.7261525988578796
# Epoch(0/1 : Batch number(115/938)  Batch loss : 0.5381573438644409
# Epoch(0/1 : Batch number(116/938)  Batch loss : 0.4608606994152069
# Epoch(0/1 : Batch number(117/938)  Batch loss : 0.7198278903961182
# Epoch(0/1 : Batch number(118/938)  Batch loss : 0.6031878590583801
# Epoch(0/1 : Batch number(119/938)  Batch loss : 0.7774343490600586
# Epoch(0/1 : Batch number(120/938)  Batch loss : 0.804768979549408
# Epoch(0/1 : Batch number(121/938)  Batch loss : 0.8642036318778992
# Epoch(0/1 : Batch number(122/938)  Batch loss : 0.6211603879928589
# Epoch(0/1 : Batch number(123/938)  Batch loss : 0.5800912976264954
# Epoch(0/1 : Batch number(124/938)  Batch loss : 0.5876534581184387
# Epoch(0/1 : Batch number(125/938)  Batch loss : 0.6286449432373047
# Epoch(0/1 : Batch number(126/938)  Batch loss : 0.5018895864486694
# Epoch(0/1 : Batch number(127/938)  Batch loss : 0.6713435649871826
# Epoch(0/1 : Batch number(128/938)  Batch loss : 0.46927589178085327
# Epoch(0/1 : Batch number(129/938)  Batch loss : 0.5754813551902771
# Epoch(0/1 : Batch number(130/938)  Batch loss : 0.4917638897895813
# Epoch(0/1 : Batch number(131/938)  Batch loss : 0.6773514151573181
# Epoch(0/1 : Batch number(132/938)  Batch loss : 0.4813414216041565
# Epoch(0/1 : Batch number(133/938)  Batch loss : 0.5637996196746826
# Epoch(0/1 : Batch number(134/938)  Batch loss : 0.648249626159668
# Epoch(0/1 : Batch number(135/938)  Batch loss : 0.5023784041404724
# Epoch(0/1 : Batch number(136/938)  Batch loss : 0.5592650175094604
# Epoch(0/1 : Batch number(137/938)  Batch loss : 0.7438940405845642
# Epoch(0/1 : Batch number(138/938)  Batch loss : 0.6021401286125183
# Epoch(0/1 : Batch number(139/938)  Batch loss : 0.6472598314285278
# Epoch(0/1 : Batch number(140/938)  Batch loss : 0.5287638902664185
# Epoch(0/1 : Batch number(141/938)  Batch loss : 0.4900952875614166
# Epoch(0/1 : Batch number(142/938)  Batch loss : 0.6232556700706482
# Epoch(0/1 : Batch number(143/938)  Batch loss : 0.5960925221443176
# Epoch(0/1 : Batch number(144/938)  Batch loss : 0.5960246920585632
# Epoch(0/1 : Batch number(145/938)  Batch loss : 0.710314929485321
# Epoch(0/1 : Batch number(146/938)  Batch loss : 0.6229567527770996
# Epoch(0/1 : Batch number(147/938)  Batch loss : 0.613910436630249
# Epoch(0/1 : Batch number(148/938)  Batch loss : 0.587123453617096
# Epoch(0/1 : Batch number(149/938)  Batch loss : 0.6082679033279419
# Epoch(0/1 : Batch number(150/938)  Batch loss : 0.5480855703353882
# Epoch(0/1 : Batch number(151/938)  Batch loss : 0.6789119839668274
# Epoch(0/1 : Batch number(152/938)  Batch loss : 0.6892081499099731
# Epoch(0/1 : Batch number(153/938)  Batch loss : 0.705482006072998
# Epoch(0/1 : Batch number(154/938)  Batch loss : 0.706684947013855
# Epoch(0/1 : Batch number(155/938)  Batch loss : 0.6233692169189453
# Epoch(0/1 : Batch number(156/938)  Batch loss : 0.6103060245513916
# Epoch(0/1 : Batch number(157/938)  Batch loss : 0.3864341378211975
# Epoch(0/1 : Batch number(158/938)  Batch loss : 0.5085484981536865
# Epoch(0/1 : Batch number(159/938)  Batch loss : 0.7433791160583496
# Epoch(0/1 : Batch number(160/938)  Batch loss : 0.4618571102619171
# Epoch(0/1 : Batch number(161/938)  Batch loss : 0.5445987582206726
# Epoch(0/1 : Batch number(162/938)  Batch loss : 0.49102094769477844
# Epoch(0/1 : Batch number(163/938)  Batch loss : 0.57488614320755
# Epoch(0/1 : Batch number(164/938)  Batch loss : 0.4874052107334137
# Epoch(0/1 : Batch number(165/938)  Batch loss : 0.4783717393875122
# Epoch(0/1 : Batch number(166/938)  Batch loss : 0.5308529138565063
# Epoch(0/1 : Batch number(167/938)  Batch loss : 0.43890833854675293
# Epoch(0/1 : Batch number(168/938)  Batch loss : 0.443403959274292
# Epoch(0/1 : Batch number(169/938)  Batch loss : 0.4635237157344818
# Epoch(0/1 : Batch number(170/938)  Batch loss : 0.6071325540542603
# Epoch(0/1 : Batch number(171/938)  Batch loss : 0.484437495470047
# Epoch(0/1 : Batch number(172/938)  Batch loss : 0.4273923933506012
# Epoch(0/1 : Batch number(173/938)  Batch loss : 0.5245840549468994
# Epoch(0/1 : Batch number(174/938)  Batch loss : 0.5308674573898315
# Epoch(0/1 : Batch number(175/938)  Batch loss : 0.5604634284973145
# Epoch(0/1 : Batch number(176/938)  Batch loss : 0.5747466683387756
# Epoch(0/1 : Batch number(177/938)  Batch loss : 0.49542737007141113
# Epoch(0/1 : Batch number(178/938)  Batch loss : 0.5810244083404541
# Epoch(0/1 : Batch number(179/938)  Batch loss : 0.5951254367828369
# Epoch(0/1 : Batch number(180/938)  Batch loss : 0.6279014348983765
# Epoch(0/1 : Batch number(181/938)  Batch loss : 0.5549609065055847
# Epoch(0/1 : Batch number(182/938)  Batch loss : 0.5249083638191223
# Epoch(0/1 : Batch number(183/938)  Batch loss : 0.8562198877334595
# Epoch(0/1 : Batch number(184/938)  Batch loss : 0.6578057408332825
# Epoch(0/1 : Batch number(185/938)  Batch loss : 0.5320397019386292
# Epoch(0/1 : Batch number(186/938)  Batch loss : 0.34890392422676086
# Epoch(0/1 : Batch number(187/938)  Batch loss : 0.389604777097702
# Epoch(0/1 : Batch number(188/938)  Batch loss : 0.44711655378341675
# Epoch(0/1 : Batch number(189/938)  Batch loss : 0.46556830406188965
# Epoch(0/1 : Batch number(190/938)  Batch loss : 0.40176069736480713
# Epoch(0/1 : Batch number(191/938)  Batch loss : 0.3819490671157837
# Epoch(0/1 : Batch number(192/938)  Batch loss : 0.4987969398498535
# Epoch(0/1 : Batch number(193/938)  Batch loss : 0.5793197154998779
# Epoch(0/1 : Batch number(194/938)  Batch loss : 0.6096143126487732
# Epoch(0/1 : Batch number(195/938)  Batch loss : 0.4816820025444031
# Epoch(0/1 : Batch number(196/938)  Batch loss : 0.6863900423049927
# Epoch(0/1 : Batch number(197/938)  Batch loss : 0.6677821278572083
# Epoch(0/1 : Batch number(198/938)  Batch loss : 0.5449832677841187
# Epoch(0/1 : Batch number(199/938)  Batch loss : 0.6351321935653687
# Epoch(0/1 : Batch number(200/938)  Batch loss : 0.47924137115478516
# Epoch(0/1 : Batch number(201/938)  Batch loss : 0.6075747609138489
# Epoch(0/1 : Batch number(202/938)  Batch loss : 0.7322251796722412
# Epoch(0/1 : Batch number(203/938)  Batch loss : 0.6531848907470703
# Epoch(0/1 : Batch number(204/938)  Batch loss : 0.5337781310081482
# Epoch(0/1 : Batch number(205/938)  Batch loss : 0.4195808470249176
# Epoch(0/1 : Batch number(206/938)  Batch loss : 0.5830663442611694
# Epoch(0/1 : Batch number(207/938)  Batch loss : 0.35645371675491333
# Epoch(0/1 : Batch number(208/938)  Batch loss : 0.6649373769760132
# Epoch(0/1 : Batch number(209/938)  Batch loss : 0.4252067506313324
# Epoch(0/1 : Batch number(210/938)  Batch loss : 0.4914020299911499
# Epoch(0/1 : Batch number(211/938)  Batch loss : 0.6223515272140503
# Epoch(0/1 : Batch number(212/938)  Batch loss : 0.49499571323394775
# Epoch(0/1 : Batch number(213/938)  Batch loss : 0.5203585028648376
# Epoch(0/1 : Batch number(214/938)  Batch loss : 0.5697891712188721
# Epoch(0/1 : Batch number(215/938)  Batch loss : 0.5359933972358704
# Epoch(0/1 : Batch number(216/938)  Batch loss : 0.5170562267303467
# Epoch(0/1 : Batch number(217/938)  Batch loss : 0.4775455594062805
# Epoch(0/1 : Batch number(218/938)  Batch loss : 0.6884166598320007
# Epoch(0/1 : Batch number(219/938)  Batch loss : 0.619509756565094
# Epoch(0/1 : Batch number(220/938)  Batch loss : 0.5745397806167603
# Epoch(0/1 : Batch number(221/938)  Batch loss : 0.4306151568889618
# Epoch(0/1 : Batch number(222/938)  Batch loss : 0.73409104347229
# Epoch(0/1 : Batch number(223/938)  Batch loss : 0.35731035470962524
# Epoch(0/1 : Batch number(224/938)  Batch loss : 0.65936279296875
# Epoch(0/1 : Batch number(225/938)  Batch loss : 0.8312960863113403
# Epoch(0/1 : Batch number(226/938)  Batch loss : 0.5291630029678345
# Epoch(0/1 : Batch number(227/938)  Batch loss : 0.5855361223220825
# Epoch(0/1 : Batch number(228/938)  Batch loss : 0.39326611161231995
# Epoch(0/1 : Batch number(229/938)  Batch loss : 0.47714751958847046
# Epoch(0/1 : Batch number(230/938)  Batch loss : 0.5944755673408508
# Epoch(0/1 : Batch number(231/938)  Batch loss : 0.5418825149536133
# Epoch(0/1 : Batch number(232/938)  Batch loss : 0.3250585198402405
# Epoch(0/1 : Batch number(233/938)  Batch loss : 0.6547167897224426
# Epoch(0/1 : Batch number(234/938)  Batch loss : 0.3594459593296051
# Epoch(0/1 : Batch number(235/938)  Batch loss : 0.4569902718067169
# Epoch(0/1 : Batch number(236/938)  Batch loss : 0.4543079435825348
# Epoch(0/1 : Batch number(237/938)  Batch loss : 0.5093514919281006
# Epoch(0/1 : Batch number(238/938)  Batch loss : 0.4602466821670532
# Epoch(0/1 : Batch number(239/938)  Batch loss : 0.3894556164741516
# Epoch(0/1 : Batch number(240/938)  Batch loss : 0.48441269993782043
# Epoch(0/1 : Batch number(241/938)  Batch loss : 0.5671648383140564
# Epoch(0/1 : Batch number(242/938)  Batch loss : 0.5338044762611389
# Epoch(0/1 : Batch number(243/938)  Batch loss : 0.5095793008804321
# Epoch(0/1 : Batch number(244/938)  Batch loss : 0.566913902759552
# Epoch(0/1 : Batch number(245/938)  Batch loss : 0.5744105577468872
# Epoch(0/1 : Batch number(246/938)  Batch loss : 0.4122571647167206
# Epoch(0/1 : Batch number(247/938)  Batch loss : 0.5021040439605713
# Epoch(0/1 : Batch number(248/938)  Batch loss : 0.41743144392967224
# Epoch(0/1 : Batch number(249/938)  Batch loss : 0.5460813045501709
# Epoch(0/1 : Batch number(250/938)  Batch loss : 0.39655816555023193
# Epoch(0/1 : Batch number(251/938)  Batch loss : 0.46484100818634033
# Epoch(0/1 : Batch number(252/938)  Batch loss : 0.581413209438324
# Epoch(0/1 : Batch number(253/938)  Batch loss : 0.5024941563606262
# Epoch(0/1 : Batch number(254/938)  Batch loss : 0.6055939793586731
# Epoch(0/1 : Batch number(255/938)  Batch loss : 0.5576996803283691
# Epoch(0/1 : Batch number(256/938)  Batch loss : 0.3310399353504181
# Epoch(0/1 : Batch number(257/938)  Batch loss : 0.5203638076782227
# Epoch(0/1 : Batch number(258/938)  Batch loss : 0.6593688130378723
# Epoch(0/1 : Batch number(259/938)  Batch loss : 0.47521108388900757
# Epoch(0/1 : Batch number(260/938)  Batch loss : 0.8080312013626099
# Epoch(0/1 : Batch number(261/938)  Batch loss : 0.5682315230369568
# Epoch(0/1 : Batch number(262/938)  Batch loss : 0.6188743114471436
# Epoch(0/1 : Batch number(263/938)  Batch loss : 0.4809085428714752
# Epoch(0/1 : Batch number(264/938)  Batch loss : 0.4415452480316162
# Epoch(0/1 : Batch number(265/938)  Batch loss : 0.5674425959587097
# Epoch(0/1 : Batch number(266/938)  Batch loss : 0.6214313507080078
# Epoch(0/1 : Batch number(267/938)  Batch loss : 0.45434272289276123
# Epoch(0/1 : Batch number(268/938)  Batch loss : 0.669609546661377
# Epoch(0/1 : Batch number(269/938)  Batch loss : 0.4589315354824066
# Epoch(0/1 : Batch number(270/938)  Batch loss : 0.4412148892879486
# Epoch(0/1 : Batch number(271/938)  Batch loss : 0.7039041519165039
# Epoch(0/1 : Batch number(272/938)  Batch loss : 0.457359254360199
# Epoch(0/1 : Batch number(273/938)  Batch loss : 0.4502786695957184
# Epoch(0/1 : Batch number(274/938)  Batch loss : 0.41533854603767395
# Epoch(0/1 : Batch number(275/938)  Batch loss : 0.45397090911865234
# Epoch(0/1 : Batch number(276/938)  Batch loss : 0.3620457947254181
# Epoch(0/1 : Batch number(277/938)  Batch loss : 0.3427165150642395
# Epoch(0/1 : Batch number(278/938)  Batch loss : 0.42160964012145996
# Epoch(0/1 : Batch number(279/938)  Batch loss : 0.3344345688819885
# Epoch(0/1 : Batch number(280/938)  Batch loss : 0.33746519684791565
# Epoch(0/1 : Batch number(281/938)  Batch loss : 0.572564959526062
# Epoch(0/1 : Batch number(282/938)  Batch loss : 0.4787154495716095
# Epoch(0/1 : Batch number(283/938)  Batch loss : 0.5163170099258423
# Epoch(0/1 : Batch number(284/938)  Batch loss : 0.6911706924438477
# Epoch(0/1 : Batch number(285/938)  Batch loss : 0.5461945533752441
# Epoch(0/1 : Batch number(286/938)  Batch loss : 0.39399978518486023
# Epoch(0/1 : Batch number(287/938)  Batch loss : 0.5883558988571167
# Epoch(0/1 : Batch number(288/938)  Batch loss : 0.5207778811454773
# Epoch(0/1 : Batch number(289/938)  Batch loss : 0.3611409366130829
# Epoch(0/1 : Batch number(290/938)  Batch loss : 0.44204580783843994
# Epoch(0/1 : Batch number(291/938)  Batch loss : 0.44794654846191406
# Epoch(0/1 : Batch number(292/938)  Batch loss : 0.39732277393341064
# Epoch(0/1 : Batch number(293/938)  Batch loss : 0.4948537349700928
# Epoch(0/1 : Batch number(294/938)  Batch loss : 0.3814978301525116
# Epoch(0/1 : Batch number(295/938)  Batch loss : 0.5895692110061646
# Epoch(0/1 : Batch number(296/938)  Batch loss : 0.36893585324287415
# Epoch(0/1 : Batch number(297/938)  Batch loss : 0.560957133769989
# Epoch(0/1 : Batch number(298/938)  Batch loss : 0.594240128993988
# Epoch(0/1 : Batch number(299/938)  Batch loss : 0.4502013325691223
# Epoch(0/1 : Batch number(300/938)  Batch loss : 0.5228968262672424
# Epoch(0/1 : Batch number(301/938)  Batch loss : 0.5494887828826904
# Epoch(0/1 : Batch number(302/938)  Batch loss : 0.7385066747665405
# Epoch(0/1 : Batch number(303/938)  Batch loss : 0.5612542033195496
# Epoch(0/1 : Batch number(304/938)  Batch loss : 0.5355991125106812
# Epoch(0/1 : Batch number(305/938)  Batch loss : 0.4076422452926636
# Epoch(0/1 : Batch number(306/938)  Batch loss : 0.32247379422187805
# Epoch(0/1 : Batch number(307/938)  Batch loss : 0.5763775706291199
# Epoch(0/1 : Batch number(308/938)  Batch loss : 0.32240164279937744
# Epoch(0/1 : Batch number(309/938)  Batch loss : 0.46111688017845154
# Epoch(0/1 : Batch number(310/938)  Batch loss : 0.4427639842033386
# Epoch(0/1 : Batch number(311/938)  Batch loss : 0.6354525089263916
# Epoch(0/1 : Batch number(312/938)  Batch loss : 0.4319595992565155
# Epoch(0/1 : Batch number(313/938)  Batch loss : 0.42120271921157837
# Epoch(0/1 : Batch number(314/938)  Batch loss : 0.44217339158058167
# Epoch(0/1 : Batch number(315/938)  Batch loss : 0.5840041041374207
# Epoch(0/1 : Batch number(316/938)  Batch loss : 0.6160640120506287
# Epoch(0/1 : Batch number(317/938)  Batch loss : 0.48831984400749207
# Epoch(0/1 : Batch number(318/938)  Batch loss : 0.4359164535999298
# Epoch(0/1 : Batch number(319/938)  Batch loss : 0.27716121077537537
# Epoch(0/1 : Batch number(320/938)  Batch loss : 0.3494671881198883
# Epoch(0/1 : Batch number(321/938)  Batch loss : 0.5407266616821289
# Epoch(0/1 : Batch number(322/938)  Batch loss : 0.376468300819397
# Epoch(0/1 : Batch number(323/938)  Batch loss : 0.4222202003002167
# Epoch(0/1 : Batch number(324/938)  Batch loss : 0.24130550026893616
# Epoch(0/1 : Batch number(325/938)  Batch loss : 0.3976700007915497
# Epoch(0/1 : Batch number(326/938)  Batch loss : 0.575827956199646
# Epoch(0/1 : Batch number(327/938)  Batch loss : 0.3129681348800659
# Epoch(0/1 : Batch number(328/938)  Batch loss : 0.5939759612083435
# Epoch(0/1 : Batch number(329/938)  Batch loss : 0.49331748485565186
# Epoch(0/1 : Batch number(330/938)  Batch loss : 0.5824164748191833
# Epoch(0/1 : Batch number(331/938)  Batch loss : 0.3736225664615631
# Epoch(0/1 : Batch number(332/938)  Batch loss : 0.44130197167396545
# Epoch(0/1 : Batch number(333/938)  Batch loss : 0.39228925108909607
# Epoch(0/1 : Batch number(334/938)  Batch loss : 0.3883286416530609
# Epoch(0/1 : Batch number(335/938)  Batch loss : 0.5108340978622437
# Epoch(0/1 : Batch number(336/938)  Batch loss : 0.37207716703414917
# Epoch(0/1 : Batch number(337/938)  Batch loss : 0.642709493637085
# Epoch(0/1 : Batch number(338/938)  Batch loss : 0.4973307251930237
# Epoch(0/1 : Batch number(339/938)  Batch loss : 0.39293164014816284
# Epoch(0/1 : Batch number(340/938)  Batch loss : 0.5635586977005005
# Epoch(0/1 : Batch number(341/938)  Batch loss : 0.7961211800575256
# Epoch(0/1 : Batch number(342/938)  Batch loss : 0.6213812232017517
# Epoch(0/1 : Batch number(343/938)  Batch loss : 0.6006458401679993
# Epoch(0/1 : Batch number(344/938)  Batch loss : 0.48361244797706604
# Epoch(0/1 : Batch number(345/938)  Batch loss : 0.5994920134544373
# Epoch(0/1 : Batch number(346/938)  Batch loss : 0.5547657608985901
# Epoch(0/1 : Batch number(347/938)  Batch loss : 0.5588722229003906
# Epoch(0/1 : Batch number(348/938)  Batch loss : 0.6123353242874146
# Epoch(0/1 : Batch number(349/938)  Batch loss : 0.36712387204170227
# Epoch(0/1 : Batch number(350/938)  Batch loss : 0.40172120928764343
# Epoch(0/1 : Batch number(351/938)  Batch loss : 0.40340396761894226
# Epoch(0/1 : Batch number(352/938)  Batch loss : 0.5638301372528076
# Epoch(0/1 : Batch number(353/938)  Batch loss : 0.4111841320991516
# Epoch(0/1 : Batch number(354/938)  Batch loss : 0.5453568696975708
# Epoch(0/1 : Batch number(355/938)  Batch loss : 0.422633558511734
# Epoch(0/1 : Batch number(356/938)  Batch loss : 0.7343997359275818
# Epoch(0/1 : Batch number(357/938)  Batch loss : 0.49417462944984436
# Epoch(0/1 : Batch number(358/938)  Batch loss : 0.48098304867744446
# Epoch(0/1 : Batch number(359/938)  Batch loss : 0.5188258290290833
# Epoch(0/1 : Batch number(360/938)  Batch loss : 0.41573384404182434
# Epoch(0/1 : Batch number(361/938)  Batch loss : 0.4868229329586029
# Epoch(0/1 : Batch number(362/938)  Batch loss : 0.40342289209365845
# Epoch(0/1 : Batch number(363/938)  Batch loss : 0.389226496219635
# Epoch(0/1 : Batch number(364/938)  Batch loss : 0.42658185958862305
# Epoch(0/1 : Batch number(365/938)  Batch loss : 0.43361765146255493
# Epoch(0/1 : Batch number(366/938)  Batch loss : 0.461481511592865
# Epoch(0/1 : Batch number(367/938)  Batch loss : 0.5811921954154968
# Epoch(0/1 : Batch number(368/938)  Batch loss : 0.38286206126213074
# Epoch(0/1 : Batch number(369/938)  Batch loss : 0.348926305770874
# Epoch(0/1 : Batch number(370/938)  Batch loss : 0.42947378754615784
# Epoch(0/1 : Batch number(371/938)  Batch loss : 0.4110267162322998
# Epoch(0/1 : Batch number(372/938)  Batch loss : 0.5165426731109619
# Epoch(0/1 : Batch number(373/938)  Batch loss : 0.5306362509727478
# Epoch(0/1 : Batch number(374/938)  Batch loss : 0.3834307789802551
# Epoch(0/1 : Batch number(375/938)  Batch loss : 0.4980877637863159
# Epoch(0/1 : Batch number(376/938)  Batch loss : 0.4513969123363495
# Epoch(0/1 : Batch number(377/938)  Batch loss : 0.5393705368041992
# Epoch(0/1 : Batch number(378/938)  Batch loss : 0.5701179504394531
# Epoch(0/1 : Batch number(379/938)  Batch loss : 0.29109710454940796
# Epoch(0/1 : Batch number(380/938)  Batch loss : 0.44714879989624023
# Epoch(0/1 : Batch number(381/938)  Batch loss : 0.3186739683151245
# Epoch(0/1 : Batch number(382/938)  Batch loss : 0.42365890741348267
# Epoch(0/1 : Batch number(383/938)  Batch loss : 0.40433087944984436
# Epoch(0/1 : Batch number(384/938)  Batch loss : 0.33616355061531067
# Epoch(0/1 : Batch number(385/938)  Batch loss : 0.40499088168144226
# Epoch(0/1 : Batch number(386/938)  Batch loss : 0.2328052818775177
# Epoch(0/1 : Batch number(387/938)  Batch loss : 0.5316888093948364
# Epoch(0/1 : Batch number(388/938)  Batch loss : 0.2599845826625824
# Epoch(0/1 : Batch number(389/938)  Batch loss : 0.29398342967033386
# Epoch(0/1 : Batch number(390/938)  Batch loss : 0.4690761864185333
# Epoch(0/1 : Batch number(391/938)  Batch loss : 0.4120272994041443
# Epoch(0/1 : Batch number(392/938)  Batch loss : 0.3505360782146454
# Epoch(0/1 : Batch number(393/938)  Batch loss : 0.39551302790641785
# Epoch(0/1 : Batch number(394/938)  Batch loss : 0.4782436490058899
# Epoch(0/1 : Batch number(395/938)  Batch loss : 0.45800092816352844
# Epoch(0/1 : Batch number(396/938)  Batch loss : 0.37300828099250793
# Epoch(0/1 : Batch number(397/938)  Batch loss : 0.5190824866294861
# Epoch(0/1 : Batch number(398/938)  Batch loss : 0.5131120085716248
# Epoch(0/1 : Batch number(399/938)  Batch loss : 0.5880403518676758
# Epoch(0/1 : Batch number(400/938)  Batch loss : 0.5364964008331299
# Epoch(0/1 : Batch number(401/938)  Batch loss : 0.5060547590255737
# Epoch(0/1 : Batch number(402/938)  Batch loss : 0.5740211009979248
# Epoch(0/1 : Batch number(403/938)  Batch loss : 0.3089267909526825
# Epoch(0/1 : Batch number(404/938)  Batch loss : 0.3925081789493561
# Epoch(0/1 : Batch number(405/938)  Batch loss : 0.5685107707977295
# Epoch(0/1 : Batch number(406/938)  Batch loss : 0.6150412559509277
# Epoch(0/1 : Batch number(407/938)  Batch loss : 0.39339566230773926
# Epoch(0/1 : Batch number(408/938)  Batch loss : 0.3305147588253021
# Epoch(0/1 : Batch number(409/938)  Batch loss : 0.569145143032074
# Epoch(0/1 : Batch number(410/938)  Batch loss : 0.41806909441947937
# Epoch(0/1 : Batch number(411/938)  Batch loss : 0.41334131360054016
# Epoch(0/1 : Batch number(412/938)  Batch loss : 0.4863014221191406
# Epoch(0/1 : Batch number(413/938)  Batch loss : 0.2668853998184204
# Epoch(0/1 : Batch number(414/938)  Batch loss : 0.40798139572143555
# Epoch(0/1 : Batch number(415/938)  Batch loss : 0.393993616104126
# Epoch(0/1 : Batch number(416/938)  Batch loss : 0.4793989658355713
# Epoch(0/1 : Batch number(417/938)  Batch loss : 0.45454642176628113
# Epoch(0/1 : Batch number(418/938)  Batch loss : 0.3668217658996582
# Epoch(0/1 : Batch number(419/938)  Batch loss : 0.45948082208633423
# Epoch(0/1 : Batch number(420/938)  Batch loss : 0.47537529468536377
# Epoch(0/1 : Batch number(421/938)  Batch loss : 0.329196572303772
# Epoch(0/1 : Batch number(422/938)  Batch loss : 0.408155620098114
# Epoch(0/1 : Batch number(423/938)  Batch loss : 0.5242142677307129
# Epoch(0/1 : Batch number(424/938)  Batch loss : 0.5012128353118896
# Epoch(0/1 : Batch number(425/938)  Batch loss : 0.37016043066978455
# Epoch(0/1 : Batch number(426/938)  Batch loss : 0.3148157298564911
# Epoch(0/1 : Batch number(427/938)  Batch loss : 0.4155864119529724
# Epoch(0/1 : Batch number(428/938)  Batch loss : 0.595248818397522
# Epoch(0/1 : Batch number(429/938)  Batch loss : 0.4092409610748291
# Epoch(0/1 : Batch number(430/938)  Batch loss : 0.4728323221206665
# Epoch(0/1 : Batch number(431/938)  Batch loss : 0.3052973449230194
# Epoch(0/1 : Batch number(432/938)  Batch loss : 0.2846159338951111
# Epoch(0/1 : Batch number(433/938)  Batch loss : 0.3976055085659027
# Epoch(0/1 : Batch number(434/938)  Batch loss : 0.4120277166366577
# Epoch(0/1 : Batch number(435/938)  Batch loss : 0.3472965955734253
# Epoch(0/1 : Batch number(436/938)  Batch loss : 0.4478173553943634
# Epoch(0/1 : Batch number(437/938)  Batch loss : 0.268743097782135
# Epoch(0/1 : Batch number(438/938)  Batch loss : 0.40453392267227173
# Epoch(0/1 : Batch number(439/938)  Batch loss : 0.34180372953414917
# Epoch(0/1 : Batch number(440/938)  Batch loss : 0.5603297352790833
# Epoch(0/1 : Batch number(441/938)  Batch loss : 0.4923259913921356
# Epoch(0/1 : Batch number(442/938)  Batch loss : 0.3611137270927429
# Epoch(0/1 : Batch number(443/938)  Batch loss : 0.42252397537231445
# Epoch(0/1 : Batch number(444/938)  Batch loss : 0.37605172395706177
# Epoch(0/1 : Batch number(445/938)  Batch loss : 0.45470476150512695
# Epoch(0/1 : Batch number(446/938)  Batch loss : 0.39910730719566345
# Epoch(0/1 : Batch number(447/938)  Batch loss : 0.43888431787490845
# Epoch(0/1 : Batch number(448/938)  Batch loss : 0.29503217339515686
# Epoch(0/1 : Batch number(449/938)  Batch loss : 0.30813559889793396
# Epoch(0/1 : Batch number(450/938)  Batch loss : 0.5237702131271362
# Epoch(0/1 : Batch number(451/938)  Batch loss : 0.36962348222732544
# Epoch(0/1 : Batch number(452/938)  Batch loss : 0.4774845540523529
# Epoch(0/1 : Batch number(453/938)  Batch loss : 0.3854125440120697
# Epoch(0/1 : Batch number(454/938)  Batch loss : 0.5703940987586975
# Epoch(0/1 : Batch number(455/938)  Batch loss : 0.4773958921432495
# Epoch(0/1 : Batch number(456/938)  Batch loss : 0.5141600966453552
# Epoch(0/1 : Batch number(457/938)  Batch loss : 0.4484337270259857
# Epoch(0/1 : Batch number(458/938)  Batch loss : 0.30722248554229736
# Epoch(0/1 : Batch number(459/938)  Batch loss : 0.48652201890945435
# Epoch(0/1 : Batch number(460/938)  Batch loss : 0.35541245341300964
# Epoch(0/1 : Batch number(461/938)  Batch loss : 0.41716110706329346
# Epoch(0/1 : Batch number(462/938)  Batch loss : 0.44698742032051086
# Epoch(0/1 : Batch number(463/938)  Batch loss : 0.4192110002040863
# Epoch(0/1 : Batch number(464/938)  Batch loss : 0.5702670216560364
# Epoch(0/1 : Batch number(465/938)  Batch loss : 0.5220509171485901
# Epoch(0/1 : Batch number(466/938)  Batch loss : 0.5225662589073181
# Epoch(0/1 : Batch number(467/938)  Batch loss : 0.6869444847106934
# Epoch(0/1 : Batch number(468/938)  Batch loss : 0.5188477635383606
# Epoch(0/1 : Batch number(469/938)  Batch loss : 0.3814479112625122
# Epoch(0/1 : Batch number(470/938)  Batch loss : 0.4336787462234497
# Epoch(0/1 : Batch number(471/938)  Batch loss : 0.2710871994495392
# Epoch(0/1 : Batch number(472/938)  Batch loss : 0.5139761567115784
# Epoch(0/1 : Batch number(473/938)  Batch loss : 0.5015361905097961
# Epoch(0/1 : Batch number(474/938)  Batch loss : 0.4932602643966675
# Epoch(0/1 : Batch number(475/938)  Batch loss : 0.38865482807159424
# Epoch(0/1 : Batch number(476/938)  Batch loss : 0.5083461999893188
# Epoch(0/1 : Batch number(477/938)  Batch loss : 0.438376247882843
# Epoch(0/1 : Batch number(478/938)  Batch loss : 0.4954620897769928
# Epoch(0/1 : Batch number(479/938)  Batch loss : 0.37938833236694336
# Epoch(0/1 : Batch number(480/938)  Batch loss : 0.3598637580871582
# Epoch(0/1 : Batch number(481/938)  Batch loss : 0.49940967559814453
# Epoch(0/1 : Batch number(482/938)  Batch loss : 0.25499266386032104
# Epoch(0/1 : Batch number(483/938)  Batch loss : 0.25598347187042236
# Epoch(0/1 : Batch number(484/938)  Batch loss : 0.4728367030620575
# Epoch(0/1 : Batch number(485/938)  Batch loss : 0.5265889763832092
# Epoch(0/1 : Batch number(486/938)  Batch loss : 0.4119827449321747
# Epoch(0/1 : Batch number(487/938)  Batch loss : 0.48221322894096375
# Epoch(0/1 : Batch number(488/938)  Batch loss : 0.47791606187820435
# Epoch(0/1 : Batch number(489/938)  Batch loss : 0.46105891466140747
# Epoch(0/1 : Batch number(490/938)  Batch loss : 0.5820283889770508
# Epoch(0/1 : Batch number(491/938)  Batch loss : 0.4397295415401459
# Epoch(0/1 : Batch number(492/938)  Batch loss : 0.26505666971206665
# Epoch(0/1 : Batch number(493/938)  Batch loss : 0.41647952795028687
# Epoch(0/1 : Batch number(494/938)  Batch loss : 0.37430861592292786
# Epoch(0/1 : Batch number(495/938)  Batch loss : 0.4539013206958771
# Epoch(0/1 : Batch number(496/938)  Batch loss : 0.6360672116279602
# Epoch(0/1 : Batch number(497/938)  Batch loss : 0.3678354024887085
# Epoch(0/1 : Batch number(498/938)  Batch loss : 0.4206920862197876
# Epoch(0/1 : Batch number(499/938)  Batch loss : 0.44899994134902954
# Epoch(0/1 : Batch number(500/938)  Batch loss : 0.2927822172641754
# Epoch(0/1 : Batch number(501/938)  Batch loss : 0.4116094410419464
# Epoch(0/1 : Batch number(502/938)  Batch loss : 0.420371413230896
# Epoch(0/1 : Batch number(503/938)  Batch loss : 0.33514198660850525
# Epoch(0/1 : Batch number(504/938)  Batch loss : 0.5140453577041626
# Epoch(0/1 : Batch number(505/938)  Batch loss : 0.488463819026947
# Epoch(0/1 : Batch number(506/938)  Batch loss : 0.5142241716384888
# Epoch(0/1 : Batch number(507/938)  Batch loss : 0.5205123424530029
# Epoch(0/1 : Batch number(508/938)  Batch loss : 0.4143466055393219
# Epoch(0/1 : Batch number(509/938)  Batch loss : 0.37685397267341614
# Epoch(0/1 : Batch number(510/938)  Batch loss : 0.36566367745399475
# Epoch(0/1 : Batch number(511/938)  Batch loss : 0.4598248302936554
# Epoch(0/1 : Batch number(512/938)  Batch loss : 0.49665990471839905
# Epoch(0/1 : Batch number(513/938)  Batch loss : 0.4860633313655853
# Epoch(0/1 : Batch number(514/938)  Batch loss : 0.37618398666381836
# Epoch(0/1 : Batch number(515/938)  Batch loss : 0.6996419429779053
# Epoch(0/1 : Batch number(516/938)  Batch loss : 0.344946026802063
# Epoch(0/1 : Batch number(517/938)  Batch loss : 0.46637412905693054
# Epoch(0/1 : Batch number(518/938)  Batch loss : 0.2672971785068512
# Epoch(0/1 : Batch number(519/938)  Batch loss : 0.4969850778579712
# Epoch(0/1 : Batch number(520/938)  Batch loss : 0.4415293335914612
# Epoch(0/1 : Batch number(521/938)  Batch loss : 0.4770665764808655
# Epoch(0/1 : Batch number(522/938)  Batch loss : 0.6684730648994446
# Epoch(0/1 : Batch number(523/938)  Batch loss : 0.4133199453353882
# Epoch(0/1 : Batch number(524/938)  Batch loss : 0.42037227749824524
# Epoch(0/1 : Batch number(525/938)  Batch loss : 0.2436186671257019
# Epoch(0/1 : Batch number(526/938)  Batch loss : 0.4538179039955139
# Epoch(0/1 : Batch number(527/938)  Batch loss : 0.5875486135482788
# Epoch(0/1 : Batch number(528/938)  Batch loss : 0.33993247151374817
# Epoch(0/1 : Batch number(529/938)  Batch loss : 0.5206740498542786
# Epoch(0/1 : Batch number(530/938)  Batch loss : 0.3281305730342865
# Epoch(0/1 : Batch number(531/938)  Batch loss : 0.45189476013183594
# Epoch(0/1 : Batch number(532/938)  Batch loss : 0.3660305440425873
# Epoch(0/1 : Batch number(533/938)  Batch loss : 0.22158293426036835
# Epoch(0/1 : Batch number(534/938)  Batch loss : 0.5926986336708069
# Epoch(0/1 : Batch number(535/938)  Batch loss : 0.3200741112232208
# Epoch(0/1 : Batch number(536/938)  Batch loss : 0.398227721452713
# Epoch(0/1 : Batch number(537/938)  Batch loss : 0.3264774680137634
# Epoch(0/1 : Batch number(538/938)  Batch loss : 0.4935065805912018
# Epoch(0/1 : Batch number(539/938)  Batch loss : 0.3668460547924042
# Epoch(0/1 : Batch number(540/938)  Batch loss : 0.43418240547180176
# Epoch(0/1 : Batch number(541/938)  Batch loss : 0.37336015701293945
# Epoch(0/1 : Batch number(542/938)  Batch loss : 0.2531786561012268
# Epoch(0/1 : Batch number(543/938)  Batch loss : 0.33099719882011414
# Epoch(0/1 : Batch number(544/938)  Batch loss : 0.39517834782600403
# Epoch(0/1 : Batch number(545/938)  Batch loss : 0.3683789074420929
# Epoch(0/1 : Batch number(546/938)  Batch loss : 0.3422340750694275
# Epoch(0/1 : Batch number(547/938)  Batch loss : 0.39998242259025574
# Epoch(0/1 : Batch number(548/938)  Batch loss : 0.5179279446601868
# Epoch(0/1 : Batch number(549/938)  Batch loss : 0.2586359977722168
# Epoch(0/1 : Batch number(550/938)  Batch loss : 0.36672645807266235
# Epoch(0/1 : Batch number(551/938)  Batch loss : 0.4520096480846405
# Epoch(0/1 : Batch number(552/938)  Batch loss : 0.6495903730392456
# Epoch(0/1 : Batch number(553/938)  Batch loss : 0.5340744853019714
# Epoch(0/1 : Batch number(554/938)  Batch loss : 0.4947151243686676
# Epoch(0/1 : Batch number(555/938)  Batch loss : 0.38036075234413147
# Epoch(0/1 : Batch number(556/938)  Batch loss : 0.5801127552986145
# Epoch(0/1 : Batch number(557/938)  Batch loss : 0.41654136776924133
# Epoch(0/1 : Batch number(558/938)  Batch loss : 0.41136735677719116
# Epoch(0/1 : Batch number(559/938)  Batch loss : 0.23832812905311584
# Epoch(0/1 : Batch number(560/938)  Batch loss : 0.7059617638587952
# Epoch(0/1 : Batch number(561/938)  Batch loss : 0.3969389498233795
# Epoch(0/1 : Batch number(562/938)  Batch loss : 0.408681184053421
# Epoch(0/1 : Batch number(563/938)  Batch loss : 0.31113678216934204
# Epoch(0/1 : Batch number(564/938)  Batch loss : 0.46408259868621826
# Epoch(0/1 : Batch number(565/938)  Batch loss : 0.26209118962287903
# Epoch(0/1 : Batch number(566/938)  Batch loss : 0.3464652895927429
# Epoch(0/1 : Batch number(567/938)  Batch loss : 0.5279276371002197
# Epoch(0/1 : Batch number(568/938)  Batch loss : 0.36731719970703125
# Epoch(0/1 : Batch number(569/938)  Batch loss : 0.5772115588188171
# Epoch(0/1 : Batch number(570/938)  Batch loss : 0.3767872452735901
# Epoch(0/1 : Batch number(571/938)  Batch loss : 0.3303583860397339
# Epoch(0/1 : Batch number(572/938)  Batch loss : 0.4311882555484772
# Epoch(0/1 : Batch number(573/938)  Batch loss : 0.4602331519126892
# Epoch(0/1 : Batch number(574/938)  Batch loss : 0.5829899907112122
# Epoch(0/1 : Batch number(575/938)  Batch loss : 0.28724247217178345
# Epoch(0/1 : Batch number(576/938)  Batch loss : 0.4072343111038208
# Epoch(0/1 : Batch number(577/938)  Batch loss : 0.39815443754196167
# Epoch(0/1 : Batch number(578/938)  Batch loss : 0.31006476283073425
# Epoch(0/1 : Batch number(579/938)  Batch loss : 0.33760568499565125
# Epoch(0/1 : Batch number(580/938)  Batch loss : 0.4751695394515991
# Epoch(0/1 : Batch number(581/938)  Batch loss : 0.4893700182437897
# Epoch(0/1 : Batch number(582/938)  Batch loss : 0.3876497745513916
# Epoch(0/1 : Batch number(583/938)  Batch loss : 0.43616771697998047
# Epoch(0/1 : Batch number(584/938)  Batch loss : 0.5996253490447998
# Epoch(0/1 : Batch number(585/938)  Batch loss : 0.38822585344314575
# Epoch(0/1 : Batch number(586/938)  Batch loss : 0.41655078530311584
# Epoch(0/1 : Batch number(587/938)  Batch loss : 0.4818221926689148
# Epoch(0/1 : Batch number(588/938)  Batch loss : 0.3277202844619751
# Epoch(0/1 : Batch number(589/938)  Batch loss : 0.32904958724975586
# Epoch(0/1 : Batch number(590/938)  Batch loss : 0.4757135212421417
# Epoch(0/1 : Batch number(591/938)  Batch loss : 0.20371079444885254
# Epoch(0/1 : Batch number(592/938)  Batch loss : 0.4557833969593048
# Epoch(0/1 : Batch number(593/938)  Batch loss : 0.2967395782470703
# Epoch(0/1 : Batch number(594/938)  Batch loss : 0.435187429189682
# Epoch(0/1 : Batch number(595/938)  Batch loss : 0.479849636554718
# Epoch(0/1 : Batch number(596/938)  Batch loss : 0.4374583065509796
# Epoch(0/1 : Batch number(597/938)  Batch loss : 0.3836420178413391
# Epoch(0/1 : Batch number(598/938)  Batch loss : 0.4121904671192169
# Epoch(0/1 : Batch number(599/938)  Batch loss : 0.43641388416290283
# Epoch(0/1 : Batch number(600/938)  Batch loss : 0.2688693702220917
# Epoch(0/1 : Batch number(601/938)  Batch loss : 0.5110283493995667
# Epoch(0/1 : Batch number(602/938)  Batch loss : 0.5749993324279785
# Epoch(0/1 : Batch number(603/938)  Batch loss : 0.390760600566864
# Epoch(0/1 : Batch number(604/938)  Batch loss : 0.5417234301567078
# Epoch(0/1 : Batch number(605/938)  Batch loss : 0.4561682343482971
# Epoch(0/1 : Batch number(606/938)  Batch loss : 0.4660777151584625
# Epoch(0/1 : Batch number(607/938)  Batch loss : 0.4637976586818695
# Epoch(0/1 : Batch number(608/938)  Batch loss : 0.4337829351425171
# Epoch(0/1 : Batch number(609/938)  Batch loss : 0.32810547947883606
# Epoch(0/1 : Batch number(610/938)  Batch loss : 0.31735533475875854
# Epoch(0/1 : Batch number(611/938)  Batch loss : 0.460572749376297
# Epoch(0/1 : Batch number(612/938)  Batch loss : 0.2962521016597748
# Epoch(0/1 : Batch number(613/938)  Batch loss : 0.3098291754722595
# Epoch(0/1 : Batch number(614/938)  Batch loss : 0.5616527795791626
# Epoch(0/1 : Batch number(615/938)  Batch loss : 0.5338379144668579
# Epoch(0/1 : Batch number(616/938)  Batch loss : 0.38010990619659424
# Epoch(0/1 : Batch number(617/938)  Batch loss : 0.3645492196083069
# Epoch(0/1 : Batch number(618/938)  Batch loss : 0.3310272693634033
# Epoch(0/1 : Batch number(619/938)  Batch loss : 0.42366865277290344
# Epoch(0/1 : Batch number(620/938)  Batch loss : 0.26917126774787903
# Epoch(0/1 : Batch number(621/938)  Batch loss : 0.3690795600414276
# Epoch(0/1 : Batch number(622/938)  Batch loss : 0.5437031984329224
# Epoch(0/1 : Batch number(623/938)  Batch loss : 0.4206441342830658
# Epoch(0/1 : Batch number(624/938)  Batch loss : 0.49953705072402954
# Epoch(0/1 : Batch number(625/938)  Batch loss : 0.5069703459739685
# Epoch(0/1 : Batch number(626/938)  Batch loss : 0.44589537382125854
# Epoch(0/1 : Batch number(627/938)  Batch loss : 0.4082828760147095
# Epoch(0/1 : Batch number(628/938)  Batch loss : 0.4805064797401428
# Epoch(0/1 : Batch number(629/938)  Batch loss : 0.20651030540466309
# Epoch(0/1 : Batch number(630/938)  Batch loss : 0.3613709509372711
# Epoch(0/1 : Batch number(631/938)  Batch loss : 0.4929015636444092
# Epoch(0/1 : Batch number(632/938)  Batch loss : 0.3300555348396301
# Epoch(0/1 : Batch number(633/938)  Batch loss : 0.4054238498210907
# Epoch(0/1 : Batch number(634/938)  Batch loss : 0.4477061629295349
# Epoch(0/1 : Batch number(635/938)  Batch loss : 0.5647419095039368
# Epoch(0/1 : Batch number(636/938)  Batch loss : 0.4674625098705292
# Epoch(0/1 : Batch number(637/938)  Batch loss : 0.4184201955795288
# Epoch(0/1 : Batch number(638/938)  Batch loss : 0.44005855917930603
# Epoch(0/1 : Batch number(639/938)  Batch loss : 0.4385465681552887
# Epoch(0/1 : Batch number(640/938)  Batch loss : 0.5064647197723389
# Epoch(0/1 : Batch number(641/938)  Batch loss : 0.3597431778907776
# Epoch(0/1 : Batch number(642/938)  Batch loss : 0.46347975730895996
# Epoch(0/1 : Batch number(643/938)  Batch loss : 0.5591000914573669
# Epoch(0/1 : Batch number(644/938)  Batch loss : 0.3946974575519562
# Epoch(0/1 : Batch number(645/938)  Batch loss : 0.2682374119758606
# Epoch(0/1 : Batch number(646/938)  Batch loss : 0.2504488527774811
# Epoch(0/1 : Batch number(647/938)  Batch loss : 0.5090752840042114
# Epoch(0/1 : Batch number(648/938)  Batch loss : 0.3953836262226105
# Epoch(0/1 : Batch number(649/938)  Batch loss : 0.26589706540107727
# Epoch(0/1 : Batch number(650/938)  Batch loss : 0.5949556827545166
# Epoch(0/1 : Batch number(651/938)  Batch loss : 0.583674430847168
# Epoch(0/1 : Batch number(652/938)  Batch loss : 0.3081255257129669
# Epoch(0/1 : Batch number(653/938)  Batch loss : 0.516270101070404
# Epoch(0/1 : Batch number(654/938)  Batch loss : 0.4178657829761505
# Epoch(0/1 : Batch number(655/938)  Batch loss : 0.3878326416015625
# Epoch(0/1 : Batch number(656/938)  Batch loss : 0.3892996907234192
# Epoch(0/1 : Batch number(657/938)  Batch loss : 0.48255455493927
# Epoch(0/1 : Batch number(658/938)  Batch loss : 0.3263107240200043
# Epoch(0/1 : Batch number(659/938)  Batch loss : 0.39459028840065
# Epoch(0/1 : Batch number(660/938)  Batch loss : 0.5620328783988953
# Epoch(0/1 : Batch number(661/938)  Batch loss : 0.31184685230255127
# Epoch(0/1 : Batch number(662/938)  Batch loss : 0.48371991515159607
# Epoch(0/1 : Batch number(663/938)  Batch loss : 0.3808306157588959
# Epoch(0/1 : Batch number(664/938)  Batch loss : 0.4102741777896881
# Epoch(0/1 : Batch number(665/938)  Batch loss : 0.4280353784561157
# Epoch(0/1 : Batch number(666/938)  Batch loss : 0.6601015329360962
# Epoch(0/1 : Batch number(667/938)  Batch loss : 0.30101317167282104
# Epoch(0/1 : Batch number(668/938)  Batch loss : 0.40144187211990356
# Epoch(0/1 : Batch number(669/938)  Batch loss : 0.3814440071582794
# Epoch(0/1 : Batch number(670/938)  Batch loss : 0.43463414907455444
# Epoch(0/1 : Batch number(671/938)  Batch loss : 0.562361478805542
# Epoch(0/1 : Batch number(672/938)  Batch loss : 0.34674471616744995
# Epoch(0/1 : Batch number(673/938)  Batch loss : 0.4408462345600128
# Epoch(0/1 : Batch number(674/938)  Batch loss : 0.5020363926887512
# Epoch(0/1 : Batch number(675/938)  Batch loss : 0.3865622580051422
# Epoch(0/1 : Batch number(676/938)  Batch loss : 0.4404436945915222
# Epoch(0/1 : Batch number(677/938)  Batch loss : 0.4440656900405884
# Epoch(0/1 : Batch number(678/938)  Batch loss : 0.41001778841018677
# Epoch(0/1 : Batch number(679/938)  Batch loss : 0.47401177883148193
# Epoch(0/1 : Batch number(680/938)  Batch loss : 0.32283899188041687
# Epoch(0/1 : Batch number(681/938)  Batch loss : 0.3344390094280243
# Epoch(0/1 : Batch number(682/938)  Batch loss : 0.5358139276504517
# Epoch(0/1 : Batch number(683/938)  Batch loss : 0.33942046761512756
# Epoch(0/1 : Batch number(684/938)  Batch loss : 0.4320116341114044
# Epoch(0/1 : Batch number(685/938)  Batch loss : 0.5493455529212952
# Epoch(0/1 : Batch number(686/938)  Batch loss : 0.5079052448272705
# Epoch(0/1 : Batch number(687/938)  Batch loss : 0.3492778241634369
# Epoch(0/1 : Batch number(688/938)  Batch loss : 0.35574471950531006
# Epoch(0/1 : Batch number(689/938)  Batch loss : 0.4834701120853424
# Epoch(0/1 : Batch number(690/938)  Batch loss : 0.6086166501045227
# Epoch(0/1 : Batch number(691/938)  Batch loss : 0.3135654926300049
# Epoch(0/1 : Batch number(692/938)  Batch loss : 0.2758754789829254
# Epoch(0/1 : Batch number(693/938)  Batch loss : 0.3248097896575928
# Epoch(0/1 : Batch number(694/938)  Batch loss : 0.41414278745651245
# Epoch(0/1 : Batch number(695/938)  Batch loss : 0.7052621841430664
# Epoch(0/1 : Batch number(696/938)  Batch loss : 0.3549163043498993
# Epoch(0/1 : Batch number(697/938)  Batch loss : 0.28046393394470215
# Epoch(0/1 : Batch number(698/938)  Batch loss : 0.33207204937934875
# Epoch(0/1 : Batch number(699/938)  Batch loss : 0.4556966722011566
# Epoch(0/1 : Batch number(700/938)  Batch loss : 0.3918285369873047
# Epoch(0/1 : Batch number(701/938)  Batch loss : 0.4766309857368469
# Epoch(0/1 : Batch number(702/938)  Batch loss : 0.23151683807373047
# Epoch(0/1 : Batch number(703/938)  Batch loss : 0.42531728744506836
# Epoch(0/1 : Batch number(704/938)  Batch loss : 0.3256336748600006
# Epoch(0/1 : Batch number(705/938)  Batch loss : 0.46603310108184814
# Epoch(0/1 : Batch number(706/938)  Batch loss : 0.3749128580093384
# Epoch(0/1 : Batch number(707/938)  Batch loss : 0.4033537805080414
# Epoch(0/1 : Batch number(708/938)  Batch loss : 0.34835484623908997
# Epoch(0/1 : Batch number(709/938)  Batch loss : 0.4581618309020996
# Epoch(0/1 : Batch number(710/938)  Batch loss : 0.517535924911499
# Epoch(0/1 : Batch number(711/938)  Batch loss : 0.4681127667427063
# Epoch(0/1 : Batch number(712/938)  Batch loss : 0.4962090849876404
# Epoch(0/1 : Batch number(713/938)  Batch loss : 0.49615809321403503
# Epoch(0/1 : Batch number(714/938)  Batch loss : 0.6111027598381042
# Epoch(0/1 : Batch number(715/938)  Batch loss : 0.3788720667362213
# Epoch(0/1 : Batch number(716/938)  Batch loss : 0.5107812285423279
# Epoch(0/1 : Batch number(717/938)  Batch loss : 0.39539092779159546
# Epoch(0/1 : Batch number(718/938)  Batch loss : 0.40456727147102356
# Epoch(0/1 : Batch number(719/938)  Batch loss : 0.49498847126960754
# Epoch(0/1 : Batch number(720/938)  Batch loss : 0.48521336913108826
# Epoch(0/1 : Batch number(721/938)  Batch loss : 0.555802583694458
# Epoch(0/1 : Batch number(722/938)  Batch loss : 0.30543625354766846
# Epoch(0/1 : Batch number(723/938)  Batch loss : 0.323203980922699
# Epoch(0/1 : Batch number(724/938)  Batch loss : 0.3030036687850952
# Epoch(0/1 : Batch number(725/938)  Batch loss : 0.3246690332889557
# Epoch(0/1 : Batch number(726/938)  Batch loss : 0.27910149097442627
# Epoch(0/1 : Batch number(727/938)  Batch loss : 0.33707156777381897
# Epoch(0/1 : Batch number(728/938)  Batch loss : 0.4979967772960663
# Epoch(0/1 : Batch number(729/938)  Batch loss : 0.5540305376052856
# Epoch(0/1 : Batch number(730/938)  Batch loss : 0.37799686193466187
# Epoch(0/1 : Batch number(731/938)  Batch loss : 0.5594055652618408
# Epoch(0/1 : Batch number(732/938)  Batch loss : 0.507254958152771
# Epoch(0/1 : Batch number(733/938)  Batch loss : 0.40288910269737244
# Epoch(0/1 : Batch number(734/938)  Batch loss : 0.34862804412841797
# Epoch(0/1 : Batch number(735/938)  Batch loss : 0.33274438977241516
# Epoch(0/1 : Batch number(736/938)  Batch loss : 0.3641257584095001
# Epoch(0/1 : Batch number(737/938)  Batch loss : 0.49675315618515015
# Epoch(0/1 : Batch number(738/938)  Batch loss : 0.40559107065200806
# Epoch(0/1 : Batch number(739/938)  Batch loss : 0.47099849581718445
# Epoch(0/1 : Batch number(740/938)  Batch loss : 0.5184990167617798
# Epoch(0/1 : Batch number(741/938)  Batch loss : 0.4302442967891693
# Epoch(0/1 : Batch number(742/938)  Batch loss : 0.3526981472969055
# Epoch(0/1 : Batch number(743/938)  Batch loss : 0.5086300373077393
# Epoch(0/1 : Batch number(744/938)  Batch loss : 0.34709227085113525
# Epoch(0/1 : Batch number(745/938)  Batch loss : 0.4561644196510315
# Epoch(0/1 : Batch number(746/938)  Batch loss : 0.38916152715682983
# Epoch(0/1 : Batch number(747/938)  Batch loss : 0.442274808883667
# Epoch(0/1 : Batch number(748/938)  Batch loss : 0.31604626774787903
# Epoch(0/1 : Batch number(749/938)  Batch loss : 0.46704646944999695
# Epoch(0/1 : Batch number(750/938)  Batch loss : 0.45943811535835266
# Epoch(0/1 : Batch number(751/938)  Batch loss : 0.5096551775932312
# Epoch(0/1 : Batch number(752/938)  Batch loss : 0.43382951617240906
# Epoch(0/1 : Batch number(753/938)  Batch loss : 0.47998154163360596
# Epoch(0/1 : Batch number(754/938)  Batch loss : 0.6906032562255859
# Epoch(0/1 : Batch number(755/938)  Batch loss : 0.36825719475746155
# Epoch(0/1 : Batch number(756/938)  Batch loss : 0.3984527587890625
# Epoch(0/1 : Batch number(757/938)  Batch loss : 0.3606571555137634
# Epoch(0/1 : Batch number(758/938)  Batch loss : 0.497619092464447
# Epoch(0/1 : Batch number(759/938)  Batch loss : 0.34565970301628113
# Epoch(0/1 : Batch number(760/938)  Batch loss : 0.29015323519706726
# Epoch(0/1 : Batch number(761/938)  Batch loss : 0.3503628969192505
# Epoch(0/1 : Batch number(762/938)  Batch loss : 0.5980257987976074
# Epoch(0/1 : Batch number(763/938)  Batch loss : 0.5140419602394104
# Epoch(0/1 : Batch number(764/938)  Batch loss : 0.5542984008789062
# Epoch(0/1 : Batch number(765/938)  Batch loss : 0.4396606683731079
# Epoch(0/1 : Batch number(766/938)  Batch loss : 0.5868548154830933
# Epoch(0/1 : Batch number(767/938)  Batch loss : 0.6297585368156433
# Epoch(0/1 : Batch number(768/938)  Batch loss : 0.521278440952301
# Epoch(0/1 : Batch number(769/938)  Batch loss : 0.47004103660583496
# Epoch(0/1 : Batch number(770/938)  Batch loss : 0.33631348609924316
# Epoch(0/1 : Batch number(771/938)  Batch loss : 0.5746830105781555
# Epoch(0/1 : Batch number(772/938)  Batch loss : 0.40682801604270935
# Epoch(0/1 : Batch number(773/938)  Batch loss : 0.46517741680145264
# Epoch(0/1 : Batch number(774/938)  Batch loss : 0.2710821032524109
# Epoch(0/1 : Batch number(775/938)  Batch loss : 0.49045896530151367
# Epoch(0/1 : Batch number(776/938)  Batch loss : 0.44274890422821045
# Epoch(0/1 : Batch number(777/938)  Batch loss : 0.3610953092575073
# Epoch(0/1 : Batch number(778/938)  Batch loss : 0.3239855468273163
# Epoch(0/1 : Batch number(779/938)  Batch loss : 0.35837244987487793
# Epoch(0/1 : Batch number(780/938)  Batch loss : 0.31702497601509094
# Epoch(0/1 : Batch number(781/938)  Batch loss : 0.4821588099002838
# Epoch(0/1 : Batch number(782/938)  Batch loss : 0.3486648201942444
# Epoch(0/1 : Batch number(783/938)  Batch loss : 0.17109450697898865
# Epoch(0/1 : Batch number(784/938)  Batch loss : 0.6021773219108582
# Epoch(0/1 : Batch number(785/938)  Batch loss : 0.26460254192352295
# Epoch(0/1 : Batch number(786/938)  Batch loss : 0.4253515899181366
# Epoch(0/1 : Batch number(787/938)  Batch loss : 0.3916403651237488
# Epoch(0/1 : Batch number(788/938)  Batch loss : 0.41040652990341187
# Epoch(0/1 : Batch number(789/938)  Batch loss : 0.5402037501335144
# Epoch(0/1 : Batch number(790/938)  Batch loss : 0.41736072301864624
# Epoch(0/1 : Batch number(791/938)  Batch loss : 0.3348361849784851
# Epoch(0/1 : Batch number(792/938)  Batch loss : 0.5003657937049866
# Epoch(0/1 : Batch number(793/938)  Batch loss : 0.5286288261413574
# Epoch(0/1 : Batch number(794/938)  Batch loss : 0.3539254367351532
# Epoch(0/1 : Batch number(795/938)  Batch loss : 0.36271539330482483
# Epoch(0/1 : Batch number(796/938)  Batch loss : 0.34788385033607483
# Epoch(0/1 : Batch number(797/938)  Batch loss : 0.5104477405548096
# Epoch(0/1 : Batch number(798/938)  Batch loss : 0.33422914147377014
# Epoch(0/1 : Batch number(799/938)  Batch loss : 0.47180551290512085
# Epoch(0/1 : Batch number(800/938)  Batch loss : 0.5125885605812073
# Epoch(0/1 : Batch number(801/938)  Batch loss : 0.35050544142723083
# Epoch(0/1 : Batch number(802/938)  Batch loss : 0.5040406584739685
# Epoch(0/1 : Batch number(803/938)  Batch loss : 0.5734769105911255
# Epoch(0/1 : Batch number(804/938)  Batch loss : 0.35700321197509766
# Epoch(0/1 : Batch number(805/938)  Batch loss : 0.4930029511451721
# Epoch(0/1 : Batch number(806/938)  Batch loss : 0.38414719700813293
# Epoch(0/1 : Batch number(807/938)  Batch loss : 0.4011555314064026
# Epoch(0/1 : Batch number(808/938)  Batch loss : 0.338411420583725
# Epoch(0/1 : Batch number(809/938)  Batch loss : 0.2923208773136139
# Epoch(0/1 : Batch number(810/938)  Batch loss : 0.37727513909339905
# Epoch(0/1 : Batch number(811/938)  Batch loss : 0.3392442762851715
# Epoch(0/1 : Batch number(812/938)  Batch loss : 0.2989695966243744
# Epoch(0/1 : Batch number(813/938)  Batch loss : 0.5073906183242798
# Epoch(0/1 : Batch number(814/938)  Batch loss : 0.3319086730480194
# Epoch(0/1 : Batch number(815/938)  Batch loss : 0.5723338723182678
# Epoch(0/1 : Batch number(816/938)  Batch loss : 0.4714033305644989
# Epoch(0/1 : Batch number(817/938)  Batch loss : 0.4648208022117615
# Epoch(0/1 : Batch number(818/938)  Batch loss : 0.5065507292747498
# Epoch(0/1 : Batch number(819/938)  Batch loss : 0.40507790446281433
# Epoch(0/1 : Batch number(820/938)  Batch loss : 0.455709844827652
# Epoch(0/1 : Batch number(821/938)  Batch loss : 0.19135524332523346
# Epoch(0/1 : Batch number(822/938)  Batch loss : 0.3572216331958771
# Epoch(0/1 : Batch number(823/938)  Batch loss : 0.29704299569129944
# Epoch(0/1 : Batch number(824/938)  Batch loss : 0.42081212997436523
# Epoch(0/1 : Batch number(825/938)  Batch loss : 0.27700328826904297
# Epoch(0/1 : Batch number(826/938)  Batch loss : 0.2842388451099396
# Epoch(0/1 : Batch number(827/938)  Batch loss : 0.2892797887325287
# Epoch(0/1 : Batch number(828/938)  Batch loss : 0.5064440369606018
# Epoch(0/1 : Batch number(829/938)  Batch loss : 0.41349589824676514
# Epoch(0/1 : Batch number(830/938)  Batch loss : 0.46050480008125305
# Epoch(0/1 : Batch number(831/938)  Batch loss : 0.19774411618709564
# Epoch(0/1 : Batch number(832/938)  Batch loss : 0.5104942917823792
# Epoch(0/1 : Batch number(833/938)  Batch loss : 0.29218927025794983
# Epoch(0/1 : Batch number(834/938)  Batch loss : 0.4444356858730316
# Epoch(0/1 : Batch number(835/938)  Batch loss : 0.5147528052330017
# Epoch(0/1 : Batch number(836/938)  Batch loss : 0.32473230361938477
# Epoch(0/1 : Batch number(837/938)  Batch loss : 0.502234935760498
# Epoch(0/1 : Batch number(838/938)  Batch loss : 0.5192711353302002
# Epoch(0/1 : Batch number(839/938)  Batch loss : 0.39106643199920654
# Epoch(0/1 : Batch number(840/938)  Batch loss : 0.486388236284256
# Epoch(0/1 : Batch number(841/938)  Batch loss : 0.5601654052734375
# Epoch(0/1 : Batch number(842/938)  Batch loss : 0.4359450042247772
# Epoch(0/1 : Batch number(843/938)  Batch loss : 0.5918339490890503
# Epoch(0/1 : Batch number(844/938)  Batch loss : 0.30248963832855225
# Epoch(0/1 : Batch number(845/938)  Batch loss : 0.31508854031562805
# Epoch(0/1 : Batch number(846/938)  Batch loss : 0.24986326694488525
# Epoch(0/1 : Batch number(847/938)  Batch loss : 0.32925960421562195
# Epoch(0/1 : Batch number(848/938)  Batch loss : 0.40883511304855347
# Epoch(0/1 : Batch number(849/938)  Batch loss : 0.4919418394565582
# Epoch(0/1 : Batch number(850/938)  Batch loss : 0.4822676181793213
# Epoch(0/1 : Batch number(851/938)  Batch loss : 0.2762907147407532
# Epoch(0/1 : Batch number(852/938)  Batch loss : 0.5252067446708679
# Epoch(0/1 : Batch number(853/938)  Batch loss : 0.33908510208129883
# Epoch(0/1 : Batch number(854/938)  Batch loss : 0.45035597681999207
# Epoch(0/1 : Batch number(855/938)  Batch loss : 0.5474970936775208
# Epoch(0/1 : Batch number(856/938)  Batch loss : 0.2215212732553482
# Epoch(0/1 : Batch number(857/938)  Batch loss : 0.27148643136024475
# Epoch(0/1 : Batch number(858/938)  Batch loss : 0.22464850544929504
# Epoch(0/1 : Batch number(859/938)  Batch loss : 0.39896613359451294
# Epoch(0/1 : Batch number(860/938)  Batch loss : 0.4205220937728882
# Epoch(0/1 : Batch number(861/938)  Batch loss : 0.3599083721637726
# Epoch(0/1 : Batch number(862/938)  Batch loss : 0.47069957852363586
# Epoch(0/1 : Batch number(863/938)  Batch loss : 0.2861139476299286
# Epoch(0/1 : Batch number(864/938)  Batch loss : 0.3009093403816223
# Epoch(0/1 : Batch number(865/938)  Batch loss : 0.3954866826534271
# Epoch(0/1 : Batch number(866/938)  Batch loss : 0.20403072237968445
# Epoch(0/1 : Batch number(867/938)  Batch loss : 0.4103384017944336
# Epoch(0/1 : Batch number(868/938)  Batch loss : 0.24101971089839935
# Epoch(0/1 : Batch number(869/938)  Batch loss : 0.22269415855407715
# Epoch(0/1 : Batch number(870/938)  Batch loss : 0.37904438376426697
# Epoch(0/1 : Batch number(871/938)  Batch loss : 0.5300257205963135
# Epoch(0/1 : Batch number(872/938)  Batch loss : 0.3244082033634186
# Epoch(0/1 : Batch number(873/938)  Batch loss : 0.36869528889656067
# Epoch(0/1 : Batch number(874/938)  Batch loss : 0.4841960370540619
# Epoch(0/1 : Batch number(875/938)  Batch loss : 0.297967791557312
# Epoch(0/1 : Batch number(876/938)  Batch loss : 0.27993327379226685
# Epoch(0/1 : Batch number(877/938)  Batch loss : 0.4704571068286896
# Epoch(0/1 : Batch number(878/938)  Batch loss : 0.45210546255111694
# Epoch(0/1 : Batch number(879/938)  Batch loss : 0.520540714263916
# Epoch(0/1 : Batch number(880/938)  Batch loss : 0.2840973436832428
# Epoch(0/1 : Batch number(881/938)  Batch loss : 0.4736618399620056
# Epoch(0/1 : Batch number(882/938)  Batch loss : 0.45361727476119995
# Epoch(0/1 : Batch number(883/938)  Batch loss : 0.3479565382003784
# Epoch(0/1 : Batch number(884/938)  Batch loss : 0.3965754806995392
# Epoch(0/1 : Batch number(885/938)  Batch loss : 0.3417314887046814
# Epoch(0/1 : Batch number(886/938)  Batch loss : 0.4380742013454437
# Epoch(0/1 : Batch number(887/938)  Batch loss : 0.35100850462913513
# Epoch(0/1 : Batch number(888/938)  Batch loss : 0.39283478260040283
# Epoch(0/1 : Batch number(889/938)  Batch loss : 0.2815917730331421
# Epoch(0/1 : Batch number(890/938)  Batch loss : 0.45956701040267944
# Epoch(0/1 : Batch number(891/938)  Batch loss : 0.359211802482605
# Epoch(0/1 : Batch number(892/938)  Batch loss : 0.41920387744903564
# Epoch(0/1 : Batch number(893/938)  Batch loss : 0.27522024512290955
# Epoch(0/1 : Batch number(894/938)  Batch loss : 0.37851426005363464
# Epoch(0/1 : Batch number(895/938)  Batch loss : 0.37693366408348083
# Epoch(0/1 : Batch number(896/938)  Batch loss : 0.3980235457420349
# Epoch(0/1 : Batch number(897/938)  Batch loss : 0.35604214668273926
# Epoch(0/1 : Batch number(898/938)  Batch loss : 0.3375808000564575
# Epoch(0/1 : Batch number(899/938)  Batch loss : 0.48306146264076233
# Epoch(0/1 : Batch number(900/938)  Batch loss : 0.28762343525886536
# Epoch(0/1 : Batch number(901/938)  Batch loss : 0.4259133040904999
# Epoch(0/1 : Batch number(902/938)  Batch loss : 0.34602102637290955
# Epoch(0/1 : Batch number(903/938)  Batch loss : 0.24427802860736847
# Epoch(0/1 : Batch number(904/938)  Batch loss : 0.33893877267837524
# Epoch(0/1 : Batch number(905/938)  Batch loss : 0.47654956579208374
# Epoch(0/1 : Batch number(906/938)  Batch loss : 0.3078668713569641
# Epoch(0/1 : Batch number(907/938)  Batch loss : 0.45094677805900574
# Epoch(0/1 : Batch number(908/938)  Batch loss : 0.3606155216693878
# Epoch(0/1 : Batch number(909/938)  Batch loss : 0.31174030900001526
# Epoch(0/1 : Batch number(910/938)  Batch loss : 0.24909867346286774
# Epoch(0/1 : Batch number(911/938)  Batch loss : 0.34596845507621765
# Epoch(0/1 : Batch number(912/938)  Batch loss : 0.4988850951194763
# Epoch(0/1 : Batch number(913/938)  Batch loss : 0.338314950466156
# Epoch(0/1 : Batch number(914/938)  Batch loss : 0.42405936121940613
# Epoch(0/1 : Batch number(915/938)  Batch loss : 0.31232398748397827
# Epoch(0/1 : Batch number(916/938)  Batch loss : 0.2511917054653168
# Epoch(0/1 : Batch number(917/938)  Batch loss : 0.4600304067134857
# Epoch(0/1 : Batch number(918/938)  Batch loss : 0.3139180541038513
# Epoch(0/1 : Batch number(919/938)  Batch loss : 0.3869035840034485
# Epoch(0/1 : Batch number(920/938)  Batch loss : 0.3285757303237915
# Epoch(0/1 : Batch number(921/938)  Batch loss : 0.27798688411712646
# Epoch(0/1 : Batch number(922/938)  Batch loss : 0.41920655965805054
# Epoch(0/1 : Batch number(923/938)  Batch loss : 0.4077189564704895
# Epoch(0/1 : Batch number(924/938)  Batch loss : 0.3542417883872986
# Epoch(0/1 : Batch number(925/938)  Batch loss : 0.45291274785995483
# Epoch(0/1 : Batch number(926/938)  Batch loss : 0.4792229235172272
# Epoch(0/1 : Batch number(927/938)  Batch loss : 0.5083263516426086
# Epoch(0/1 : Batch number(928/938)  Batch loss : 0.338445246219635
# Epoch(0/1 : Batch number(929/938)  Batch loss : 0.3952358663082123
# Epoch(0/1 : Batch number(930/938)  Batch loss : 0.6271200776100159
# Epoch(0/1 : Batch number(931/938)  Batch loss : 0.3442339301109314
# Epoch(0/1 : Batch number(932/938)  Batch loss : 0.48112037777900696
# Epoch(0/1 : Batch number(933/938)  Batch loss : 0.36187806725502014
# Epoch(0/1 : Batch number(934/938)  Batch loss : 0.41069933772087097
# Epoch(0/1 : Batch number(935/938)  Batch loss : 0.3726041615009308
# Epoch(0/1 : Batch number(936/938)  Batch loss : 0.4147561490535736
# Epoch(0/1 : Batch number(937/938)  Batch loss : 0.29982927441596985
# Epoch(0/1 : Batch number(938/938)  Batch loss : 0.6034165024757385
# Training loss : 0.5114302682692308

# %% [markdown]
# ## Evaluating thet network and viewing images

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## Accuracy of the model

# %%
images, labels = images.cuda(), labels.cuda() # add this line

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0


    for batch, (images, labels) in enumerate(testloader,1):
        images, labels = images.cuda(), labels.cuda() # add this line

        logps = model(images)
        output = torch.exp(logps)
        
        pred = torch.argmax(output, 1)
        total += labels.size(0)
        num_correct += (pred == labels).sum().item()
        print(f'Batch ({batch}/{len(testloader)})')
        
        if batch == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 91.875%
